# %% [markdown]
# # WeatherPy

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import json 
import requests
import time
import scipy.stats as sts
from scipy import stats
import openweathermapy.core as owm
import csv 

#Import API Key
from config import weather_api_key

# to get the city latitude and longtiude 
from citipy import citipy

# Range of latitudes and longitudes
#https://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Cities Summary

# %%
#Set up lists to hold reponse info for latitude and lontitude
lat_lngs = []
cities = []
countries = []

#Get the random lat and lng then zip together
#https://stackoverflow.com/questions/55230785/how-can-i-generate-a-seed-for-np-random-uniform
lats = np.random.uniform(low=-90.00, high=90.00, size=1500)
lngs = np.random.uniform(low=-180.00, high=180.00, size=1500)
lat_lngs = zip(lats, lngs)


#Get the nearest city based on latitude and lontitude
#https://github.com/wingchen/citipy/blob/master/tests.py
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    if city not in cities:
        cities.append(city)
        countries.append(country)

#Create DataFrame for city and country         
City_latlong_data = pd.DataFrame({"City": cities, "Country": countries})
City_latlong_data = City_latlong_data.reset_index(drop=True)
City_latlong_data.head() 

#set up additional columns to hold information
City_latlong_data["Cloudiness"] = ""
City_latlong_data["Humidity"] = ""
City_latlong_data["Date"] = ""
City_latlong_data["Max Temp"] = ""
City_latlong_data["Wind Speed"] = ""

#Print the city count
len(cities)
# Out:
# 625

# %%
#Create a dataframe to store all the latitude and longitude
Cities_df = pd.DataFrame()
Cities_df = Cities_df.append(pd.DataFrame.from_dict({ "Latitude": lats, "Longitude": lngs}))        
Cities_df

#Merge two dataframes to display all the additional columns, drop duplicates and drop nan vaulues
City_Data = [City_latlong_data, Cities_df]        
City_Data_DF = pd.concat([City_latlong_data, Cities_df], axis=1)
City_Data_DF = City_Data_DF.drop_duplicates()
City_Data_DF = City_Data_DF.dropna()
City_Data_DF = City_Data_DF.reset_index(drop=True)
City_Data_DF = pd.DataFrame(City_Data_DF)
City_Data_DF.head(20)
# Out:
#               City Country Cloudiness Humidity Date Max Temp Wind Speed  \
# 0           hobart      au
# 1          rikitea      pf
# 2           ambulu      id
# 3             igis      ch
# 4        cape town      za
# 5           dikson      ru
# 6       ellensburg      us
# 7    belushya guba      ru
# 8         hermanus      za
# 9      devils lake      us
# 10         ushuaia      ar
# 11         ballina      ie
# 12  ribeira grande      pt
# 13    sentyabrskiy      ru
# 14       taolanaro      mg
# 15            maun      bw
# 16        enumclaw      us
# 17           pevek      ru
# 18     dhrangadhra      in
# 19      nikolskoye      ru
#
#      Latitude   Longitude
# 0  -72.889249  143.382685
# 1  -60.388120 -133.390419
# 2  -12.310450  112.842907
# 3   46.970568    9.641243
# 4  -56.759346   -2.754619
# 5   82.871498   72.503527
# 6   47.384877 -120.900448
# 7   87.457357   56.364219
# 8  -69.533862   -1.365960
# 9   48.455021  -98.875620
# 10 -70.714064  -71.159180
# 11  56.662093  -10.977670
# 12  28.072091  -43.283027
# 13  37.833021  157.592237
# 14 -46.760389   56.763284
# 15 -20.336744   23.393484
# 16  46.682232 -121.716829
# 17  77.516118  166.680329
# 18  23.134854   71.465989
# 19  47.912768  175.546450

# %%
##* Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
random_selected_cities = City_Data_DF.sample(500)
#Print the selected cities Dataframe
random_selected_cities = random_selected_cities.reset_index(drop=True)
random_selected_cities = pd.DataFrame(random_selected_cities)
random_selected_cities
# Out:
#                    City Country Cloudiness Humidity Date Max Temp Wind Speed  \
# 0           grand-santi      gf
# 1    thiruvananthapuram      in
# 2              udachnyy      ru
# 3                 vaini      to
# 4             canchungo      gw
# ..                  ...     ...        ...      ...  ...      ...        ...
# 495            palm bay      us
# 496          brockville      ca
# 497                biak      id
# 498      mahadday weyne      so
# 499    valle de allende      mx
#
#       Latitude   Longitude
# 0    39.033504  122.137056
# 1    21.977548 -104.420110
# 2    47.922191   37.577266
# 3   -26.942396  172.679406
# 4   -14.520698   73.500881
# ..         ...         ...
# 495  59.290278  -21.084677
# 496 -22.247956 -115.948180
# 497   7.131549   54.426850
# 498  -5.006289  -88.466439
# 499  16.939470   84.282094
#
# [500 rows x 9 columns]

# %% [markdown]
# # Get API Calls¶

# %%
#https://gt.bootcampcontent.com/GT-Coding-Boot-Camp/gt-atl-data-pt-03-2020-u-c/blob/master/06-Python-APIs/3/Activities/04-Ins_NearestRestr/Solved/NearestRestr.ipynb
#URL for get requests to retrieve weather data - 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
     
# set up lists to hold reponse info
city_name =[]
lat = []
lon = []
temp =[]
temperature_max = []
date = []
humidity = []
wind_speed = []
country = []
cloudiness = []

#counter for data set number of calls
record_count = 1

# Loop through the list of cities and perform a request
#Used Activity 06-Python-APIs/2/Activities/10-Stu_API_Exceptions/Solved/api_exceptions.ipynb
print(f"Generating Data Retrival")

for city in cities:
    
# Try to grab the lists of city responses if availble from json response
    try:
        response = requests.get(f"{url}&q={city}").json()
        #Making sure my url printed 
#        print(response)
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temperature_max.append(response['main']['temp_max'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
        city = response['name']
        print(f"The weather API responded with:# {record_count} | {city}")
        record_count = record_count + 1

        # API CALLS TO SLEEP FOR 1 SECONDS DUE TO FREE 60 CALLS/MIN 
        time.sleep(1)
        
    
    except KeyError: 
        print("City missing...Skipping")
        
print("------------------------")
print("Generated Data Completed")
print("------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9246be5369046e9d6295393ab5911965
# Generating Data Retrival
# The weather API responded with:# 1 | Hobart
# The weather API responded with:# 2 | Rikitea
# The weather API responded with:# 3 | Ambulu
# The weather API responded with:# 4 | Igis
# The weather API responded with:# 5 | Cape Town
# The weather API responded with:# 6 | Dikson
# The weather API responded with:# 7 | Ellensburg
# City missing...Skipping
# The weather API responded with:# 8 | Hermanus
# The weather API responded with:# 9 | Devils Lake
# The weather API responded with:# 10 | Ushuaia
# The weather API responded with:# 11 | Ballina
# The weather API responded with:# 12 | Ribeira Grande
# City missing...Skipping
# City missing...Skipping
# The weather API responded with:# 13 | Maun
# The weather API responded with:# 14 | Enumclaw
# The weather API responded with:# 15 | Pevek
# The weather API responded with:# 16 | Dhrāngadhra
# The weather API responded with:# 17 | Nikolskoye
# The weather API responded with:# 18 | Çorum Province
# The weather API responded with:# 19 | Sambava
# The weather API responded with:# 20 | Pramanta
# The weather API responded with:# 21 | Bekhtery
# The weather API responded with:# 22 | Bogorodskoye
# The weather API responded with:# 23 | Mahébourg
# The weather API responded with:# 24 | Hamilton
# The weather API responded with:# 25 | Bambous Virieux
# The weather API responded with:# 26 | Jamestown
# The weather API responded with:# 27 | Punta Arenas
# The weather API responded with:# 28 | Fes
# The weather API responded with:# 29 | Montepuez
# The weather API responded with:# 30 | ‘Ewa Beach
# The weather API responded with:# 31 | Port Alfred
# The weather API responded with:# 32 | Ouadda
# The weather API responded with:# 33 | Tuatapere
# The weather API responded with:# 34 | Castro
# The weather API responded with:# 35 | George Town
# City missing...Skipping
# The weather API responded with:# 36 | Nizhniy Odes
# The weather API responded with:# 37 | Oranjestad
# The weather API responded with:# 38 | San Rafael
# The weather API responded with:# 39 | Belaya Gora
# The weather API responded with:# 40 | Avera
# The weather API responded with:# 41 | Puerto Ayora
# The weather API responded with:# 42 | Lebu
# The weather API responded with:# 43 | Atuona
# The weather API responded with:# 44 | Huangmei
# The weather API responded with:# 45 | Fortuna
# The weather API responded with:# 46 | Helong
# The weather API responded with:# 47 | Toyooka
# City missing...Skipping
# City missing...Skipping
# The weather API responded with:# 48 | Kapaa
# The weather API responded with:# 49 | Yakeshi
# The weather API responded with:# 50 | Mana
# The weather API responded with:# 51 | Bumba
# The weather API responded with:# 52 | Rome
# The weather API responded with:# 53 | Cap Malheureux
# The weather API responded with:# 54 | Sumbe
# The weather API responded with:# 55 | Chokurdakh
# The weather API responded with:# 56 | Hithadhoo
# The weather API responded with:# 57 | Qaanaaq
# The weather API responded with:# 58 | Senneterre
# The weather API responded with:# 59 | Yellowknife
# The weather API responded with:# 60 | Los Llanos de Aridane
# The weather API responded with:# 61 | Avarua
# The weather API responded with:# 62 | Khovd
# The weather API responded with:# 63 | Butaritari
# The weather API responded with:# 64 | Wanning
# The weather API responded with:# 65 | Husavik
# The weather API responded with:# 66 | Le Port
# The weather API responded with:# 67 | Bud
# The weather API responded with:# 68 | Bredasdorp
# The weather API responded with:# 69 | Mattru
# The weather API responded with:# 70 | Busselton
# The weather API responded with:# 71 | Camocim
# The weather API responded with:# 72 | Adra
# The weather API responded with:# 73 | Mount Isa
# The weather API responded with:# 74 | Sitka
# The weather API responded with:# 75 | Saint Paul Harbor
# The weather API responded with:# 76 | Torbay
# The weather API responded with:# 77 | Pecos
# The weather API responded with:# 78 | Soligalich
# The weather API responded with:# 79 | Stornoway
# The weather API responded with:# 80 | Natitingou
# The weather API responded with:# 81 | São Filipe
# The weather API responded with:# 82 | Grindavik
# The weather API responded with:# 83 | Yashkul'
# The weather API responded with:# 84 | Mataura
# City missing...Skipping
# The weather API responded with:# 85 | Albany
# The weather API responded with:# 86 | Ponta do Sol
# The weather API responded with:# 87 | Vilyuysk
# The weather API responded with:# 88 | Lázaro Cárdenas
# The weather API responded with:# 89 | Tuktoyaktuk
# The weather API responded with:# 90 | Rio de Janeiro
# The weather API responded with:# 91 | Marrakesh
# The weather API responded with:# 92 | Bluff
# The weather API responded with:# 93 | Pedernales
# The weather API responded with:# 94 | Constitución
# The weather API responded with:# 95 | Sokoto
# The weather API responded with:# 96 | Padang
# The weather API responded with:# 97 | Pekan
# The weather API responded with:# 98 | Tiarei
# The weather API responded with:# 99 | Salisbury
# The weather API responded with:# 100 | Kurumkan
# The weather API responded with:# 101 | Boguchany
# The weather API responded with:# 102 | Ixtapa
# The weather API responded with:# 103 | Quatre Cocos
# The weather API responded with:# 104 | Ayagoz
# The weather API responded with:# 105 | Wenzhou
# The weather API responded with:# 106 | Guhāgar
# The weather API responded with:# 107 | New Norfolk
# The weather API responded with:# 108 | Lishan
# City missing...Skipping
# The weather API responded with:# 109 | Salalah
# The weather API responded with:# 110 | Faanui
# The weather API responded with:# 111 | Tautira
# The weather API responded with:# 112 | Puerto Escondido
# The weather API responded with:# 113 | San Cristobal
# The weather API responded with:# 114 | Norman Wells
# The weather API responded with:# 115 | Huarmey
# The weather API responded with:# 116 | Pipili
# The weather API responded with:# 117 | Talnakh
# The weather API responded with:# 118 | Taltal
# The weather API responded with:# 119 | Sakaraha
# The weather API responded with:# 120 | Pulandian
# The weather API responded with:# 121 | Arraial do Cabo
# The weather API responded with:# 122 | Pattaya
# The weather API responded with:# 123 | Gravdal
# City missing...Skipping
# The weather API responded with:# 124 | Vao
# The weather API responded with:# 125 | Khatanga
# The weather API responded with:# 126 | Rio Branco
# The weather API responded with:# 127 | Havøysund
# The weather API responded with:# 128 | Yārāda
# City missing...Skipping
# The weather API responded with:# 129 | Severo-Kuril'sk
# The weather API responded with:# 130 | Saint-Philippe
# The weather API responded with:# 131 | Itigi
# The weather API responded with:# 132 | Yar-Sale
# City missing...Skipping
# The weather API responded with:# 133 | La Asuncion
# The weather API responded with:# 134 | Chui
# The weather API responded with:# 135 | Ivanivka
# The weather API responded with:# 136 | Alice Springs
# The weather API responded with:# 137 | Caravelas
# The weather API responded with:# 138 | Vila Velha
# The weather API responded with:# 139 | Gillette
# The weather API responded with:# 140 | Kavieng
# The weather API responded with:# 141 | Bay Roberts
# The weather API responded with:# 142 | Grand Gaube
# The weather API responded with:# 143 | Svobodnyy
# City missing...Skipping
# The weather API responded with:# 144 | Aranos
# The weather API responded with:# 145 | Ancud
# The weather API responded with:# 146 | Mar del Plata
# The weather API responded with:# 147 | Sosnovo-Ozerskoye
# City missing...Skipping
# The weather API responded with:# 148 | Longyearbyen
# The weather API responded with:# 149 | Valentín Gómez Farías
# The weather API responded with:# 150 | Isangel
# The weather API responded with:# 151 | Nanortalik
# The weather API responded with:# 152 | Mlonggo
# The weather API responded with:# 153 | Findochty
# The weather API responded with:# 154 | East London
# The weather API responded with:# 155 | Kurchum
# The weather API responded with:# 156 | Klaksvík
# The weather API responded with:# 157 | Brockville
# The weather API responded with:# 158 | Nishihara
# The weather API responded with:# 159 | Grand-Santi
# The weather API responded with:# 160 | Pangnirtung
# The weather API responded with:# 161 | Cidreira
# The weather API responded with:# 162 | Portland
# The weather API responded with:# 163 | Cabo San Lucas
# The weather API responded with:# 164 | Laas
# City missing...Skipping
# The weather API responded with:# 165 | Anadyr
# The weather API responded with:# 166 | Panguna
# The weather API responded with:# 167 | Paamiut
# The weather API responded with:# 168 | Kolokani
# The weather API responded with:# 169 | Vaini
# The weather API responded with:# 170 | Winslow
# The weather API responded with:# 171 | San Patricio
# The weather API responded with:# 172 | Alofi
# The weather API responded with:# 173 | Keroka
# The weather API responded with:# 174 | Saint Anthony
# The weather API responded with:# 175 | Bereket
# The weather API responded with:# 176 | Valle de Allende
# The weather API responded with:# 177 | Kudahuvadhoo
# The weather API responded with:# 178 | Bulgan
# The weather API responded with:# 179 | Waren
# The weather API responded with:# 180 | Port Elizabeth
# The weather API responded with:# 181 | Altamira
# The weather API responded with:# 182 | Santa Rosa
# The weather API responded with:# 183 | El Salvador
# The weather API responded with:# 184 | Kavaratti
# City missing...Skipping
# The weather API responded with:# 185 | Thompson
# The weather API responded with:# 186 | Gādarwāra
# City missing...Skipping
# The weather API responded with:# 187 | Tasiilaq
# The weather API responded with:# 188 | Xiantao
# The weather API responded with:# 189 | Hong Kong
# The weather API responded with:# 190 | Kragujevac
# The weather API responded with:# 191 | Naze
# The weather API responded with:# 192 | Ankang
# The weather API responded with:# 193 | Gornyak
# The weather API responded with:# 194 | Tiksi
# The weather API responded with:# 195 | Punta de Piedra
# The weather API responded with:# 196 | Boda
# The weather API responded with:# 197 | Klyuchi
# The weather API responded with:# 198 | Poniatowa
# The weather API responded with:# 199 | Pisco
# The weather API responded with:# 200 | Poli
# The weather API responded with:# 201 | Marawi
# The weather API responded with:# 202 | Leningradskiy
# The weather API responded with:# 203 | Deputatsky
# The weather API responded with:# 204 | Vestmannaeyjar
# The weather API responded with:# 205 | Ponta Delgada
# The weather API responded with:# 206 | Bobrov
# The weather API responded with:# 207 | Verkhotur'ye
# The weather API responded with:# 208 | Ilulissat
# The weather API responded with:# 209 | Upernavik
# The weather API responded with:# 210 | Alvarães
# The weather API responded with:# 211 | San Lazaro
# The weather API responded with:# 212 | Riberalta
# The weather API responded with:# 213 | Esperance
# The weather API responded with:# 214 | Agadez
# The weather API responded with:# 215 | Beipiao
# The weather API responded with:# 216 | Bandarbeyla
# City missing...Skipping
# The weather API responded with:# 217 | Saskylakh
# The weather API responded with:# 218 | Denpasar
# The weather API responded with:# 219 | Heihe
# The weather API responded with:# 220 | Carnarvon
# The weather API responded with:# 221 | Shache
# City missing...Skipping
# The weather API responded with:# 222 | Fairbanks
# The weather API responded with:# 223 | Nebolchi
# The weather API responded with:# 224 | San Jose
# The weather API responded with:# 225 | El Retorno
# The weather API responded with:# 226 | Ambovombe
# The weather API responded with:# 227 | Lompoc
# The weather API responded with:# 228 | San Andrés
# The weather API responded with:# 229 | Honiara
# The weather API responded with:# 230 | Kiryat Gat
# City missing...Skipping
# The weather API responded with:# 231 | Boyolangu
# The weather API responded with:# 232 | Pierre
# The weather API responded with:# 233 | Presidencia Roque Sáenz Peña
# The weather API responded with:# 234 | Korla
# City missing...Skipping
# The weather API responded with:# 235 | Half Moon Bay
# The weather API responded with:# 236 | Srednekolymsk
# The weather API responded with:# 237 | Isabela
# The weather API responded with:# 238 | Palauig
# The weather API responded with:# 239 | Gaozhou
# The weather API responded with:# 240 | Hilo
# The weather API responded with:# 241 | Carroll
# The weather API responded with:# 242 | Margate
# The weather API responded with:# 243 | Murdochville
# The weather API responded with:# 244 | Clyde River
# The weather API responded with:# 245 | Bathsheba
# The weather API responded with:# 246 | Goderich
# City missing...Skipping
# The weather API responded with:# 247 | Rørvik
# The weather API responded with:# 248 | Pishin
# The weather API responded with:# 249 | Miles City
# The weather API responded with:# 250 | Banjarmasin
# The weather API responded with:# 251 | Sibolga
# The weather API responded with:# 252 | Airai
# The weather API responded with:# 253 | Barrow
# The weather API responded with:# 254 | Kununurra
# City missing...Skipping
# The weather API responded with:# 255 | Kamenka
# The weather API responded with:# 256 | Pochutla
# The weather API responded with:# 257 | Iqaluit
# City missing...Skipping
# The weather API responded with:# 258 | Aswān
# The weather API responded with:# 259 | Cockburn Town
# The weather API responded with:# 260 | Bubaque
# The weather API responded with:# 261 | Praia
# City missing...Skipping
# The weather API responded with:# 262 | Safi
# The weather API responded with:# 263 | Contai
# The weather API responded with:# 264 | Caborca
# City missing...Skipping
# The weather API responded with:# 265 | Katsuura
# The weather API responded with:# 266 | Aksu
# The weather API responded with:# 267 | Puteyets
# The weather API responded with:# 268 | Oussouye
# The weather API responded with:# 269 | Flinders
# The weather API responded with:# 270 | Yulara
# The weather API responded with:# 271 | Cabinda
# The weather API responded with:# 272 | Lucapa
# The weather API responded with:# 273 | Natal
# The weather API responded with:# 274 | Plettenberg Bay
# The weather API responded with:# 275 | Palencia
# The weather API responded with:# 276 | Lüderitz
# City missing...Skipping
# The weather API responded with:# 277 | Saint-Leu
# The weather API responded with:# 278 | Narsaq
# The weather API responded with:# 279 | Caniço
# The weather API responded with:# 280 | Lagoa
# The weather API responded with:# 281 | Sal Rei
# The weather API responded with:# 282 | Raudeberg
# The weather API responded with:# 283 | Sheboygan
# City missing...Skipping
# The weather API responded with:# 284 | Athabasca
# The weather API responded with:# 285 | Aksarka
# The weather API responded with:# 286 | Mulegé
# The weather API responded with:# 287 | Provideniya
# The weather API responded with:# 288 | Manggar
# The weather API responded with:# 289 | Puga
# The weather API responded with:# 290 | Palmer
# The weather API responded with:# 291 | Florianópolis
# The weather API responded with:# 292 | Udachny
# The weather API responded with:# 293 | Vila Franca do Campo
# The weather API responded with:# 294 | Piteå
# The weather API responded with:# 295 | Ahipara
# The weather API responded with:# 296 | Kenai
# The weather API responded with:# 297 | Carballo
# The weather API responded with:# 298 | Balikpapan
# The weather API responded with:# 299 | Saurimo
# The weather API responded with:# 300 | La Santisima Trinidad
# The weather API responded with:# 301 | Bethel
# The weather API responded with:# 302 | Nabire
# The weather API responded with:# 303 | Shangrao
# The weather API responded with:# 304 | Arrondissement de Tarbes
# The weather API responded with:# 305 | Andenes
# The weather API responded with:# 306 | Paita
# The weather API responded with:# 307 | Vila do Maio
# The weather API responded with:# 308 | Westport
# The weather API responded with:# 309 | Yenagoa
# The weather API responded with:# 310 | Chapais
# The weather API responded with:# 311 | Bengkulu
# The weather API responded with:# 312 | Yumen
# City missing...Skipping
# The weather API responded with:# 313 | Mindelo
# The weather API responded with:# 314 | Inongo
# City missing...Skipping
# The weather API responded with:# 315 | Kloulklubed
# The weather API responded with:# 316 | Saldanha
# The weather API responded with:# 317 | Ginir
# The weather API responded with:# 318 | São João da Barra
# The weather API responded with:# 319 | Zhigansk
# The weather API responded with:# 320 | Saint-Pierre
# The weather API responded with:# 321 | Sfântu Gheorghe
# The weather API responded with:# 322 | Zhangaözen
# The weather API responded with:# 323 | Nkhotakota
# The weather API responded with:# 324 | Ozerna
# City missing...Skipping
# The weather API responded with:# 325 | Hasaki
# The weather API responded with:# 326 | Örnsköldsvik
# The weather API responded with:# 327 | Cleveland
# The weather API responded with:# 328 | Jyderup
# The weather API responded with:# 329 | Lovozero
# The weather API responded with:# 330 | Lorengau
# City missing...Skipping
# The weather API responded with:# 331 | Vuktyl
# The weather API responded with:# 332 | Svetlyy Yar
# The weather API responded with:# 333 | Vanimo
# The weather API responded with:# 334 | Kapuskasing
# The weather API responded with:# 335 | Biak
# The weather API responded with:# 336 | Boca do Acre
# The weather API responded with:# 337 | Raja
# The weather API responded with:# 338 | Albanel
# The weather API responded with:# 339 | Sangar
# The weather API responded with:# 340 | Pokhara
# The weather API responded with:# 341 | Taman'
# The weather API responded with:# 342 | Cayenne
# The weather API responded with:# 343 | Ridgeland
# The weather API responded with:# 344 | Marsh Harbour
# The weather API responded with:# 345 | Rāwatsār
# The weather API responded with:# 346 | Kahului
# The weather API responded with:# 347 | Port Macquarie
# The weather API responded with:# 348 | Santo Antônio do Leverger
# The weather API responded with:# 349 | Lukh
# City missing...Skipping
# The weather API responded with:# 350 | Xiongzhou
# The weather API responded with:# 351 | Kirakira
# The weather API responded with:# 352 | Kruisfontein
# The weather API responded with:# 353 | Pacific Grove
# The weather API responded with:# 354 | Labuhan
# The weather API responded with:# 355 | Antofagasta
# The weather API responded with:# 356 | Jinka
# The weather API responded with:# 357 | Am Timan
# The weather API responded with:# 358 | Arona
# City missing...Skipping
# The weather API responded with:# 359 | Sīwah
# The weather API responded with:# 360 | Igarka
# The weather API responded with:# 361 | Calama
# The weather API responded with:# 362 | Barra de Tecoanapa
# The weather API responded with:# 363 | Kutum
# The weather API responded with:# 364 | Līsakovsk
# The weather API responded with:# 365 | General Roca
# The weather API responded with:# 366 | Codrington
# The weather API responded with:# 367 | Alindao
# The weather API responded with:# 368 | Jaguarão
# The weather API responded with:# 369 | Great Yarmouth
# The weather API responded with:# 370 | Kiama
# The weather API responded with:# 371 | Manaure
# The weather API responded with:# 372 | Turaif
# The weather API responded with:# 373 | Kilindoni
# The weather API responded with:# 374 | Kaitangata
# The weather API responded with:# 375 | Camacha
# The weather API responded with:# 376 | Susanville
# City missing...Skipping
# The weather API responded with:# 377 | Soure
# The weather API responded with:# 378 | Launceston
# The weather API responded with:# 379 | Tūkrah
# The weather API responded with:# 380 | Tual
# The weather API responded with:# 381 | Chernyshevskiy
# The weather API responded with:# 382 | Lake Shasta
# The weather API responded with:# 383 | Atasū
# The weather API responded with:# 384 | Barranca
# The weather API responded with:# 385 | Shingū
# The weather API responded with:# 386 | Cap-aux-Meules
# The weather API responded with:# 387 | Llaillay
# The weather API responded with:# 388 | Ust-Kuyga
# The weather API responded with:# 389 | Pandan
# The weather API responded with:# 390 | Kuito
# The weather API responded with:# 391 | Nizwá
# City missing...Skipping
# The weather API responded with:# 392 | Thinadhoo
# The weather API responded with:# 393 | Taoudenni
# The weather API responded with:# 394 | Laguna
# The weather API responded with:# 395 | San Policarpo
# The weather API responded with:# 396 | Caxito
# The weather API responded with:# 397 | Cherskiy
# The weather API responded with:# 398 | Quesnel
# The weather API responded with:# 399 | Ostrovnoy
# The weather API responded with:# 400 | Badiraguato
# The weather API responded with:# 401 | Berlevåg
# The weather API responded with:# 402 | Olavarría
# The weather API responded with:# 403 | San Ramon
# The weather API responded with:# 404 | Faya
# The weather API responded with:# 405 | Bykovo
# The weather API responded with:# 406 | Porto Santo
# The weather API responded with:# 407 | Saint-François
# The weather API responded with:# 408 | Ulaanbaatar
# The weather API responded with:# 409 | Shebunino
# The weather API responded with:# 410 | Abu Samrah
# The weather API responded with:# 411 | Haines Junction
# The weather API responded with:# 412 | Tilichiki
# The weather API responded with:# 413 | Henties Bay
# The weather API responded with:# 414 | Sungai Penuh
# The weather API responded with:# 415 | Salekhard
# The weather API responded with:# 416 | Muros
# The weather API responded with:# 417 | Dodge City
# The weather API responded with:# 418 | George
# The weather API responded with:# 419 | Chimbote
# The weather API responded with:# 420 | Murakami
# The weather API responded with:# 421 | Mossamedes
# The weather API responded with:# 422 | Nome
# The weather API responded with:# 423 | Ayorou
# The weather API responded with:# 424 | Geraldton
# The weather API responded with:# 425 | Richards Bay
# The weather API responded with:# 426 | Phetchaburi
# The weather API responded with:# 427 | Coihueco
# The weather API responded with:# 428 | Schongau
# The weather API responded with:# 429 | San Quintín
# The weather API responded with:# 430 | Tiznit Province
# The weather API responded with:# 431 | Saint-Augustin
# The weather API responded with:# 432 | Mocuba
# The weather API responded with:# 433 | Simbahan
# The weather API responded with:# 434 | Tecolutla
# The weather API responded with:# 435 | Baruun-Urt
# The weather API responded with:# 436 | Mirny
# The weather API responded with:# 437 | Jieshi
# The weather API responded with:# 438 | Medicine Hat
# The weather API responded with:# 439 | Buchanan
# The weather API responded with:# 440 | Carutapera
# City missing...Skipping
# The weather API responded with:# 441 | Dingle
# The weather API responded with:# 442 | Port Hardy
# The weather API responded with:# 443 | São José da Coroa Grande
# The weather API responded with:# 444 | Unity
# The weather API responded with:# 445 | Aklavik
# The weather API responded with:# 446 | Sennar
# The weather API responded with:# 447 | Zhezkazgan
# The weather API responded with:# 448 | Bogandinskiy
# The weather API responded with:# 449 | Gdov
# The weather API responded with:# 450 | Okhotsk
# The weather API responded with:# 451 | Saint-Michel-des-Saints
# The weather API responded with:# 452 | Palana
# City missing...Skipping
# The weather API responded with:# 453 | Emporia
# The weather API responded with:# 454 | Samarai
# City missing...Skipping
# The weather API responded with:# 455 | Kostanay
# The weather API responded with:# 456 | Ilo
# The weather API responded with:# 457 | Chake Chake
# The weather API responded with:# 458 | Bilibino
# The weather API responded with:# 459 | Ugoofaaru
# The weather API responded with:# 460 | Mackay
# The weather API responded with:# 461 | Sorata
# The weather API responded with:# 462 | Omboué
# City missing...Skipping
# The weather API responded with:# 463 | Porto Velho
# The weather API responded with:# 464 | Bouillante
# The weather API responded with:# 465 | Sittwe
# The weather API responded with:# 466 | Woodward
# City missing...Skipping
# The weather API responded with:# 467 | Aitape
# City missing...Skipping
# The weather API responded with:# 468 | Gorom-Gorom
# The weather API responded with:# 469 | Irbeyskoye
# The weather API responded with:# 470 | Nioki
# The weather API responded with:# 471 | Kitimat
# The weather API responded with:# 472 | Satara
# The weather API responded with:# 473 | Haimen
# The weather API responded with:# 474 | Villa Carlos Paz
# The weather API responded with:# 475 | Dalbandin
# The weather API responded with:# 476 | Atar
# The weather API responded with:# 477 | Eureka
# The weather API responded with:# 478 | Tromsø
# The weather API responded with:# 479 | Koslan
# The weather API responded with:# 480 | Ballarat
# The weather API responded with:# 481 | Ucluelet
# The weather API responded with:# 482 | Sur
# The weather API responded with:# 483 | Qui Nhon
# The weather API responded with:# 484 | Ürümqi
# The weather API responded with:# 485 | Sobolevo
# City missing...Skipping
# The weather API responded with:# 486 | Zhicheng
# The weather API responded with:# 487 | Tongliao
# The weather API responded with:# 488 | Ouésso
# The weather API responded with:# 489 | Hofn
# The weather API responded with:# 490 | Lata
# The weather API responded with:# 491 | Port Keats
# The weather API responded with:# 492 | Christchurch
# The weather API responded with:# 493 | Praia
# The weather API responded with:# 494 | Sørland
# The weather API responded with:# 495 | Nantucket
# The weather API responded with:# 496 | Limbang
# The weather API responded with:# 497 | Makakilo City
# The weather API responded with:# 498 | Trat
# The weather API responded with:# 499 | Vysha
# The weather API responded with:# 500 | Churapcha
# The weather API responded with:# 501 | Wau
# The weather API responded with:# 502 | Morón
# The weather API responded with:# 503 | Humaitá
# The weather API responded with:# 504 | Sinnamary
# The weather API responded with:# 505 | Elizabeth City
# The weather API responded with:# 506 | Imbituba
# City missing...Skipping
# The weather API responded with:# 507 | Salta
# The weather API responded with:# 508 | Vostok
# The weather API responded with:# 509 | Bitung
# The weather API responded with:# 510 | Gaoua
# The weather API responded with:# 511 | Egvekinot
# The weather API responded with:# 512 | Canchungo
# The weather API responded with:# 513 | Matara
# The weather API responded with:# 514 | Ust-Nera
# City missing...Skipping
# The weather API responded with:# 515 | Port Moresby
# The weather API responded with:# 516 | Acaraú
# The weather API responded with:# 517 | Robertsport
# The weather API responded with:# 518 | Koyima
# The weather API responded with:# 519 | Bonavista
# The weather API responded with:# 520 | Ust'-Omchug
# City missing...Skipping
# The weather API responded with:# 521 | Buluang
# The weather API responded with:# 522 | Witbank
# The weather API responded with:# 523 | Malbork
# The weather API responded with:# 524 | Palm Bay
# The weather API responded with:# 525 | Oparino
# The weather API responded with:# 526 | Santa Maria
# City missing...Skipping
# The weather API responded with:# 527 | Yangi Marg`ilon
# The weather API responded with:# 528 | Mauá
# The weather API responded with:# 529 | Tianpeng
# The weather API responded with:# 530 | Departamento de Maldonado
# The weather API responded with:# 531 | Viedma
# The weather API responded with:# 532 | Trivandrum
# The weather API responded with:# 533 | Methóni
# The weather API responded with:# 534 | Hailun
# The weather API responded with:# 535 | Bataiporã
# The weather API responded with:# 536 | Rabo de Peixe
# The weather API responded with:# 537 | Bārmer
# The weather API responded with:# 538 | Kisangani
# The weather API responded with:# 539 | Buala
# The weather API responded with:# 540 | Benalla
# The weather API responded with:# 541 | Rosarito
# The weather API responded with:# 542 | Puerto Madero
# The weather API responded with:# 543 | Lavrentiya
# The weather API responded with:# 544 | Micheweni
# City missing...Skipping
# The weather API responded with:# 545 | Howell
# The weather API responded with:# 546 | Arbazh
# The weather API responded with:# 547 | Caruray
# City missing...Skipping
# The weather API responded with:# 548 | Chulym
# The weather API responded with:# 549 | Marzuq
# The weather API responded with:# 550 | Magadan
# The weather API responded with:# 551 | Okha
# The weather API responded with:# 552 | Kayerkan
# The weather API responded with:# 553 | Herat Province
# The weather API responded with:# 554 | Cabedelo
# The weather API responded with:# 555 | Karratha
# The weather API responded with:# 556 | Lékoni
# The weather API responded with:# 557 | Sola
# The weather API responded with:# 558 | Gamba
# The weather API responded with:# 559 | Olinda
# The weather API responded with:# 560 | Aden
# The weather API responded with:# 561 | Kidal
# The weather API responded with:# 562 | Saint-Joseph
# The weather API responded with:# 563 | Iporá
# The weather API responded with:# 564 | Manaquiri
# The weather API responded with:# 565 | Quaraí
# The weather API responded with:# 566 | Aloleng
# The weather API responded with:# 567 | Talara
# The weather API responded with:# 568 | Yantal'
# The weather API responded with:# 569 | Kamsack
# The weather API responded with:# 570 | High Level
# The weather API responded with:# 571 | São Sebastião
# The weather API responded with:# 572 | Necochea
# The weather API responded with:# 573 | Ca Mau
# The weather API responded with:# 574 | Gemeente Wageningen
# The weather API responded with:# 575 | Karoi
# The weather API responded with:# 576 | Port Hedland
# The weather API responded with:# 577 | Teguise
# ------------------------
# Generated Data Completed
# ------------------------

# %%
#checking the counts and making sure the information is there needed
# ERROR RECEIVED ABOUT valueerror: arrays must all be same length
print(len(cities), len(country), len(cloudiness), len(humidity), len(date), len(temperature_max),
     len(wind_speed), len(lat), len(lon))
# Out:
# 625 577 577 577 577 577 577 577 577

# %% [markdown]
# # RAW DATA

# %%
city_weatherpy_dict = {"City": cities, "Country": country, 
                       "Cloudiness %": cloudiness, "Humidity": humidity,
                       "Date": date, "Max Temp (F)": temperature_max,
                       "Wind Speed (mph)": wind_speed, "Latitude": lat,
                       "Longitude": lon
                      }
city_weatherpy_data = pd.DataFrame.from_dict(city_weatherpy_dict, orient='index')
city_weatherpy_data.transpose()
# Out:
#              City Country Cloudiness % Humidity        Date Max Temp (F)  \
# 0          hobart      AU           75       81  1587333184         51.8
# 1         rikitea      PF          100       68  1587333375        76.87
# 2          ambulu      ID          100       76  1587333225        78.46
# 3            igis      CH          100       60  1587333227        54.59
# 4       cape town      ZA           75       77  1587333059           64
# ..            ...     ...          ...      ...         ...          ...
# 620        ca mau    None         None     None        None         None
# 621    wageningen    None         None     None        None         None
# 622         karoi    None         None     None        None         None
# 623  port hedland    None         None     None        None         None
# 624       teguise    None         None     None        None         None
#
#     Wind Speed (mph) Latitude Longitude
# 0               6.93   -42.88    147.33
# 1               6.96   -23.12   -134.97
# 2               2.91    -8.35    113.61
# 3               3.33    46.95      9.57
# 4              17.22   -33.93     18.42
# ..               ...      ...       ...
# 620             None     None      None
# 621             None     None      None
# 622             None     None      None
# 623             None     None      None
# 624             None     None      None
#
# [625 rows x 9 columns]

# %%
# When I printed my code the columns were labeled as the rows vice versa so I found I needed to use T to transpose the data back. It fixed the issue and I was also able to print the csv file correctly as well. 
transposed_data = city_weatherpy_data.T
transposed_data
# Out:
#              City Country Cloudiness % Humidity        Date Max Temp (F)  \
# 0          hobart      AU           75       81  1587333184         51.8
# 1         rikitea      PF          100       68  1587333375        76.87
# 2          ambulu      ID          100       76  1587333225        78.46
# 3            igis      CH          100       60  1587333227        54.59
# 4       cape town      ZA           75       77  1587333059           64
# ..            ...     ...          ...      ...         ...          ...
# 620        ca mau    None         None     None        None         None
# 621    wageningen    None         None     None        None         None
# 622         karoi    None         None     None        None         None
# 623  port hedland    None         None     None        None         None
# 624       teguise    None         None     None        None         None
#
#     Wind Speed (mph) Latitude Longitude
# 0               6.93   -42.88    147.33
# 1               6.96   -23.12   -134.97
# 2               2.91    -8.35    113.61
# 3               3.33    46.95      9.57
# 4              17.22   -33.93     18.42
# ..               ...      ...       ...
# 620             None     None      None
# 621             None     None      None
# 622             None     None      None
# 623             None     None      None
# 624             None     None      None
#
# [625 rows x 9 columns]

# %%
#Droping the empty rows that are listed as none above which leaves me with 577 cities
transposed_data.dropna(inplace=True)
transposed_data
# Out:
#              City Country Cloudiness % Humidity        Date Max Temp (F)  \
# 0          hobart      AU           75       81  1587333184         51.8
# 1         rikitea      PF          100       68  1587333375        76.87
# 2          ambulu      ID          100       76  1587333225        78.46
# 3            igis      CH          100       60  1587333227        54.59
# 4       cape town      ZA           75       77  1587333059           64
# ..            ...     ...          ...      ...         ...          ...
# 572  komsomolskiy      VN            0       81  1587334020        78.53
# 573          maua      NL            0       40  1587334021           54
# 574      tianpeng      ZW           65       62  1587334022        62.91
# 575     maldonado      AU           74       94  1587334023         75.2
# 576        viedma      ES           75       72  1587334024         66.2
#
#     Wind Speed (mph) Latitude Longitude
# 0               6.93   -42.88    147.33
# 1               6.96   -23.12   -134.97
# 2               2.91    -8.35    113.61
# 3               3.33    46.95      9.57
# 4              17.22   -33.93     18.42
# ..               ...      ...       ...
# 572             3.69     9.18    105.15
# 573            12.75    51.97      5.67
# 574             4.92   -16.81     29.69
# 575             3.36   -20.32    118.57
# 576             6.93    29.06    -13.56
#
# [577 rows x 9 columns]

# %%
#Output for my csv file
transposed_data.to_csv("./output_data/what_weatherpy_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f0dd92dedf0e> in <module>
#       1 #Output for my csv file
# ----> 2 transposed_data.to_csv("./output_data/what_weatherpy_data.csv")
#
# NameError: name 'transposed_data' is not defined

# %%
#Read my Output file to make sure data is formatted correctly for my csv file
transposed_data = pd.read_csv("./output_data/what_weatherpy_data.csv")
transposed_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a012dc919030> in <module>
#       1 #Read my Output file to make sure data is formatted correctly for my csv file
# ----> 2 transposed_data = pd.read_csv("./output_data/what_weatherpy_data.csv", index_col=False)
#       3 transposed_data.head()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Plotting the Data - Latitude VS Temperature (F) plot
#     * Save a CSV of all retrieved data and a PNG image for each scatter plot.
#     * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
#     * For max intensity in the heat map, try setting it to the highest humidity found in the data set.

# %%
from datetime import datetime
date_stamp = datetime.date(datetime.now())
print(date_stamp)
# Out:
# 2020-04-19

# %%
#Plotting the Data - Latitude VS Temperature (F) plot 
x_values = transposed_data['Latitude']
y_values = transposed_data['Max Temp (F)']
plt.scatter(x_values, y_values, c="blue", edgecolors="black")

plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title(f"Latitude VS Max Temperature (F)  {date_stamp}")
plt.grid()
plt.show()
plt.savefig("./output_data/Latitude_VS_Temperature.png")

# %% [markdown]
# #After each plot add a sentence or too explaining what the code is and analyzing.
#
#
# *The scatter above is showing the relationship between latitude vs max temperature. As the city position is closer to the latitude of the Equator which is 0 the temps are above 70 degrees or more. If the latitude if farther away from the Equator the tempertature will decrease.

# %% [markdown]
# # Humidity (%) vs. Latitude

# %%
#Create a scatter plot for Humidity (%) vs. Latitude
x_values = transposed_data['Latitude']
y_values = transposed_data['Humidity']
plt.scatter(x_values, y_values, c="blue", edgecolors="black")
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(-2, 120)
plt.title(f"Latitude VS Humidity (%) {date_stamp}")
plt.savefig("./output_data/Latitude_VS_Humidity.png")
plt.show()

# %% [markdown]
# #After each plot add a sentence or too explaining what the code is and analyzing.
#     After looking at the scatter plot it looks like there are a several cities with high humidity % around 70% to 100% near the Equator and also between 60Lat to 80Lat shows a significant number of high humidity above 80%.

# %% [markdown]
# # Cloudiness (%) vs. Latitude

# %%
#Create a scatter plot for Cloudiness (%) vs. Latitude
x_values = transposed_data['Latitude']
y_values = transposed_data['Cloudiness %']
plt.scatter(x_values, y_values, c="blue", edgecolors="black")
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.ylim(-20, 120)
plt.title(f"Latitude VS Cloudiness % {date_stamp}")
plt.savefig("./output_data/Latitude_VS_Cloudiness.png")
plt.show()

# %% [markdown]
# There doesn't seem to be any relationship between the cloudiness and the position of the cities.

# %% [markdown]
# # Wind Speed (mph) vs. Latitude

# %%
#Create a scatter plot for Wind Speed (mph) vs. Latitude
x_values = transposed_data['Latitude']
y_values = transposed_data['Wind Speed (mph)']
plt.scatter(x_values, y_values, c="blue", edgecolors="black")
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"Latitude VS Wind Speed (mph) {date_stamp}")
plt.savefig("./output_data/Latitude_VS_WindSpeed.png")
plt.show()

# %% [markdown]
# There doesn't seem to be a difference in the wind speed and the position of the cities. There are multiple cities with a wind speed of 0 to 5 between the latitude of -40 to 70 in the southern area. But there are very minimial windspeeds in the northern part of the graph.

# %% [markdown]
# # Create a linear regression plot & Create the DataFrames for the hemispheres
#
# #Your second requirement is to run linear regression on each relationship, only this time separating them into Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude):
#
# * Northern Hemisphere - Temperature (F) vs. Latitude
# * Southern Hemisphere - Temperature (F) vs. Latitude
# * Northern Hemisphere - Humidity (%) vs. Latitude
# * Southern Hemisphere - Humidity (%) vs. Latitude
# * Northern Hemisphere - Cloudiness (%) vs. Latitude
# * Southern Hemisphere - Cloudiness (%) vs. Latitude
# * Northern Hemisphere - Wind Speed (mph) vs. Latitude
# * Southern Hemisphere - Wind Speed (mph) vs. Latitude

# %%
#Northern Hemipshere is everything above the Equator >= 0
#Southern Hemipshere is everything below the Equator < 0
North_Hem_df = transposed_data[transposed_data["Latitude"]>= 0]
South_Hem_df = transposed_data[transposed_data["Latitude"]< 0]

# %% [markdown]
# # Northern Hemisphere - Temperature (F) vs. Latitude

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress

# Create a Scatter Plot for temperature vs latitude
x_values = North_Hem_df['Latitude']
y_values = North_Hem_df['Max Temp (F)']

 # Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title(f"Northern Hemisphere - Temperature (F) vs. Latitude {date_stamp}")
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.show()      
plt.savefig("./output_data/NorthernHemisphere-TemperatureVSLatitude.png")

# Print r square value
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.7649019599210908

# %% [markdown]
# # Southern Hemisphere - Temperature (F) vs. Latitude

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress

x_values = South_Hem_df['Latitude']
y_values = South_Hem_df['Max Temp (F)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title(f"Southern Hemisphere - Temperature (F) vs. Latitude {date_stamp}")

plt.show()
# Print r square value
print(f"The r-squared is: {rvalue**2}")

plt.savefig("./output_data/SouthernHemisphere-TemperatureVSLatitude.png")
# Out:
# The r-squared is: 0.44190325847039624

# %% [markdown]
# # Northern Hemisphere - Humidity (%) vs. Latitude

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress

x_values = North_Hem_df['Latitude']
y_values = North_Hem_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title(f"Northern Hemisphere - Temperature (F) vs. Latitude {date_stamp}")
plt.show()

# Print r square value
print(f"The r-squared is: {rvalue**2}")
plt.savefig("./output_data/NorthernHemisphere-HumidityVSLatitude.png")
plt.show()
# Out:
# The r-squared is: 0.060740235087442564

# %% [markdown]
# # Southern Hemisphere - Humidity (%) vs. Latitude

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress

x_values = South_Hem_df["Latitude"]
y_values = South_Hem_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title(f"Southern Hemisphere - Humidity % vs. Latitude {date_stamp}")
plt.show()
# Print r square value
print(f"The r-squared is: {rvalue**2}")

plt.savefig("./output_data/SouthernHemisphere-HumidityVSLatitude.png")
# Out:
# The r-squared is: 0.05511993038639405

# %% [markdown]
# # Northern Hemisphere - Cloudiness (%) vs. Latitude

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress

x_values = North_Hem_df["Latitude"]
y_values = North_Hem_df["Cloudiness %"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.title(f"Northern Hemisphere - Cloudiness (%) vs. Latitude {date_stamp}")
plt.show()
# Print r square value
print(f"The r-squared is: {rvalue**2}")

plt.savefig("./output_data/NorthernHemisphere-CloudinessVSLatitude.png")
plt.show()
# Out:
# The r-squared is: 0.012669274720511995

# %% [markdown]
# # Southern Hemisphere - Cloudiness (%) vs. Latitude

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress

x_values = South_Hem_df["Latitude"]
y_values = South_Hem_df["Cloudiness %"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.title(f"Southern Hemisphere - Cloudiness (%) vs. Latitude {date_stamp}")
plt.show()
# Print r square value
print(f"The r-squared is: {rvalue**2}")

plt.savefig("./output_data/SouthernHemisphere-CloudinessVSLatitude.png")
plt.show()
# Out:
# The r-squared is: 0.02307289745432128

# %% [markdown]
# # Northern Hemisphere - Wind Speed (mph) vs. Latitude

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress

x_values = North_Hem_df["Latitude"]
y_values = North_Hem_df["Wind Speed (mph)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"Northern Hemisphere - Wind Speed (mph) vs. Latitude {date_stamp}")
plt.show()
# Print r square value
print(f"The r-squared is: {rvalue**2}")


plt.savefig("./output_data/NorthernHemisphere-TemperatureVSLatitude.png")
plt.show()
# Out:
# The r-squared is: 0.030486942625173496

# %% [markdown]
# # Southern Hemisphere - Wind Speed (mph) vs. Latitude

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress

# Create a Scatter Plot for temperature vs latitude
x_values = South_Hem_df['Latitude']
y_values = South_Hem_df['Wind Speed (mph)']

 # Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title(f"Southern Hemisphere - Wind Speed (mph) vs. Latitude {date_stamp}")
plt.show()
# Print r square value
print(f"The r-squared is: {rvalue**2}")

plt.savefig("./output_data/SouthernHemisphere-WindSpeedVSLatitude.png")
# Out:
# The r-squared is: 0.09025341633317713
